# %% [markdown]
# # Transformation     # 1
#
# ## Two samples-overlapping spreadsheets into two intersection-only spreadsheets.
# * Samples x Phenotypes (SxP) must have the same phenotypes.
# * They must have some sample names in common.

# %%
import os
import numpy as np
import pandas as pd
import knpackage.toolbox as kn

# %% [markdown]
# #### Get two dataframes, match up the sample names and output two dataframes with those matching sample names.

# %%
def get_common_samples_data_frames(sxp_1_df, sxp_2_df):
    """ 
    Args:
        sxp_1_df:      samples x phenotypes dataframe (sxp_1_df = kn.get_spreadsheet_df(sxp_filename_1))
        sxp_2_df:      samples x phenotypes dataframe
    Returns:
        sxp_1_trim_df: samples x phenotypes with only sample names in both input dataframes
        sxp_2_trim_df: samples x phenotypes with only sample names in both input dataframes
    """
    sxp_1_gene_names = kn.extract_spreadsheet_gene_names(sxp_1_df)
    sxp_2_gene_names = kn.extract_spreadsheet_gene_names(sxp_2_df)
    common_samples_list = kn.find_common_node_names(sxp_1_gene_names, sxp_2_gene_names)
    
    return sxp_1_df.loc[common_samples_list], sxp_2_df.loc[common_samples_list]

# %% [markdown]
# ##### Create the test data; split a samples x phenotypes dataframe into two samples-overlapping  dataframes.

# %%
data_source_directory = '../data/transform_data'

spreadsheet_1_df = kn.get_spreadsheet_df(os.path.join(data_source_directory, 'spreadsheet_One.txt'))
# spreadsheet_1_df = kn.get_spreadsheet_df(os.path.join(data_source_directory, 'gene_samples_1.tsv'))
spreadsheet_2_df = kn.get_spreadsheet_df(os.path.join(data_source_directory, 'spreadsheet_Two.txt'))

# %%
df_1, df_2 = get_common_samples_data_frames(spreadsheet_1_df, spreadsheet_2_df)
df_1
# Out:
#               days_to_death  days_to_last  days_survival  diag_age  \
# sample_id
# TCGA-A5-A0GA          543.0           NaN            543        67
# TCGA-A5-A0GU            NaN         495.0            495        58
# TCGA-A5-A0GV            NaN         485.0            485        67
# TCGA-A5-A0GB            NaN         275.0            275        65
# TCGA-A5-A0GE            NaN        2717.0           2717        38
# TCGA-A5-A0R7            NaN          40.0             40        55
# TCGA-A5-A0GJ            NaN        1447.0           1447        44
# TCGA-A5-A0G5            NaN         790.0            790        73
# TCGA-A5-A0GN            NaN        1477.0           1477        65
# TCGA-A5-A0GG            NaN        2516.0           2516        76
# TCGA-A5-A0GR            NaN         780.0            780        69
# TCGA-A5-A0G1         3251.0           NaN           3251        67
# TCGA-A5-A0GI            NaN        1750.0           1750        63
# TCGA-A5-A0RA            NaN         555.0            555        68
# TCGA-A5-A0GX            NaN         924.0            924        53
# TCGA-A5-A0R8            NaN         125.0            125        81
# TCGA-A5-A0G3            NaN        1079.0           1079        61
#
#                                    race               ethnicity  gender
# sample_id
# TCGA-A5-A0GA                      white  not hispanic or latino  female
# TCGA-A5-A0GU                      white                     NaN  female
# TCGA-A5-A0GV                      white  not hispanic or latino  female
# TCGA-A5-A0GB                      white                     NaN  female
# TCGA-A5-A0GE                      asian  not hispanic or latino  female
# TCGA-A5-A0R7                      white  not hispanic or latino  female
# TCGA-A5-A0GJ                      white  not hispanic or latino  female
# TCGA-A5-A0G5  black or african american                     NaN  female
# TCGA-A5-A0GN                      white  not hispanic or latino  female
# TCGA-A5-A0GG  black or african american  not hispanic or latino  female
# TCGA-A5-A0GR  black or african american  not hispanic or latino  female
# TCGA-A5-A0G1                      white  not hispanic or latino  female
# TCGA-A5-A0GI                      white  not hispanic or latino  female
# TCGA-A5-A0RA                      white  not hispanic or latino  female
# TCGA-A5-A0GX                      white                     NaN  female
# TCGA-A5-A0R8                      white  not hispanic or latino  female
# TCGA-A5-A0G3  black or african american                     NaN  female

# %%
df_2
# Out:
#              ICDO3site        stage stage_simple  stage_ismeta    grade  \
# sample_id
# TCGA-A5-A0GA     c54.1  stage iiic2          iii             0  grade 3
# TCGA-A5-A0GU     c54.1     stage ia            i             0  grade 1
# TCGA-A5-A0GV     c54.1     stage ia            i             0  grade 1
# TCGA-A5-A0GB     c54.1     stage ib            i             0  grade 3
# TCGA-A5-A0GE     c54.1     stage ia            i             0  grade 2
# TCGA-A5-A0R7     c54.1     stage ia            i             0  grade 2
# TCGA-A5-A0GJ     c54.1     stage ia            i             0  grade 2
# TCGA-A5-A0G5     c54.1     stage ib            i             0  grade 3
# TCGA-A5-A0GN     c54.1     stage ib            i             0  grade 1
# TCGA-A5-A0GG     c54.1     stage ia            i             0  grade 1
# TCGA-A5-A0GR     c54.1     stage ia            i             0  grade 2
# TCGA-A5-A0G1     c54.1     stage ia            i             0  grade 3
# TCGA-A5-A0GI     c54.1     stage ia            i             0  grade 2
# TCGA-A5-A0RA     c54.1     stage ib            i             0  grade 2
# TCGA-A5-A0GX     c54.1     stage ia            i             0  grade 2
# TCGA-A5-A0R8     c54.1     stage ib            i             0  grade 2
# TCGA-A5-A0G3     c54.1  stage iiic2          iii             0  grade 3
#
#                  grade_simple residual
# sample_id
# TCGA-A5-A0GA       High Grade       r0
# TCGA-A5-A0GU  Low grade (1,2)       r0
# TCGA-A5-A0GV  Low grade (1,2)       r0
# TCGA-A5-A0GB       High Grade       r0
# TCGA-A5-A0GE  Low grade (1,2)       r0
# TCGA-A5-A0R7  Low grade (1,2)       r0
# TCGA-A5-A0GJ  Low grade (1,2)       r0
# TCGA-A5-A0G5       High Grade       r0
# TCGA-A5-A0GN  Low grade (1,2)       r0
# TCGA-A5-A0GG  Low grade (1,2)       r0
# TCGA-A5-A0GR  Low grade (1,2)       r0
# TCGA-A5-A0G1       High Grade       r0
# TCGA-A5-A0GI  Low grade (1,2)       r0
# TCGA-A5-A0RA  Low grade (1,2)       r0
# TCGA-A5-A0GX  Low grade (1,2)       r0
# TCGA-A5-A0R8  Low grade (1,2)       r0
# TCGA-A5-A0G3       High Grade       r0
