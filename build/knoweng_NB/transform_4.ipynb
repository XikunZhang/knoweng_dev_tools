# %% [markdown]
#     Givin a genes x samples dataframe and a samples classification dictionary, return a datframe of averages for
#     each catagory

# %%
import os
import numpy as np
import pandas as pd
import knpackage.toolbox as kn

# %%
# get the input data
data_source_directory = './transform_data'
spreadsheet_df = kn.get_spreadsheet_df(os.path.join(data_source_directory, 'gene_samples_small.tsv'))
labels_df = pd.read_csv(os.path.join(data_source_directory, 'gene_samples_small_labels.tsv'), 
                        sep='\t', index_col=0, header=None)
print(labels_df)
spreadsheet_df
# Out:
#            1
# 0
# MCF7       1
# HCC38      0
# NCI-H1437  2
# TCCSUP     1
# HCT-116    0
# 22RV1      0
# A549       1
# HCC1954    0
# SW948      2
# CAL-51     0
# NCI-H1563  2
#                  MCF7  HCC38  NCI-H1437  TCCSUP  HCT-116  22RV1  A549  \
# ENSG00000158411     0      0          0       0        0      0     0
# ENSG00000214357     0      0          0       0        0      0     0
# ENSG00000258597     0      0          0       0        0      0     0
# ENSG00000134757     1      0          0       0        0      0     0
# ENSG00000155792     0      0          0       0        1      0     0
# ENSG00000049541     0      0          0       0        0      0     0
# ENSG00000115226     0      0          0       0        0      0     0
# ENSG00000125633     0      0          0       0        0      0     0
# ENSG00000243414     0      0          0       0        0      0     0
# ENSG00000102384     0      1          0       0        0      0     0
# ENSG00000121680     1      0          0       0        0      0     0
# ENSG00000187005     0      0          0       0        0      0     0
# ENSG00000009694     1      1          0       0        1      1     1
# ENSG00000111785     0      0          0       0        0      0     0
# ENSG00000128590     0      0          0       0        1      0     0
# ENSG00000141506     0      0          0       0        0      0     0
# ENSG00000123200     1      0          0       0        1      0     0
# ENSG00000115602     0      0          0       0        0      0     0
# ENSG00000168743     0      0          0       0        0      0     0
# ENSG00000197430     0      0          0       0        0      0     0
# ENSG00000281038     0      0          1       0        0      0     0
# ENSG00000070366     0      0          0       0        1      0     0
# ENSG00000124091     0      0          0       0        0      0     0
# ENSG00000130307     0      0          0       0        1      0     0
#
#                  HCC1954  SW948  CAL-51  NCI-H1563
# ENSG00000158411        0      0       0          0
# ENSG00000214357        0      0       0          0
# ENSG00000258597        0      0       0          0
# ENSG00000134757        0      0       1          0
# ENSG00000155792        0      0       1          0
# ENSG00000049541        0      0       0          0
# ENSG00000115226        0      0       0          0
# ENSG00000125633        0      0       0          0
# ENSG00000243414        0      1       0          0
# ENSG00000102384        0      0       0          1
# ENSG00000121680        0      0       0          0
# ENSG00000187005        0      0       0          0
# ENSG00000009694        0      1       1          1
# ENSG00000111785        0      0       0          0
# ENSG00000128590        0      0       0          0
# ENSG00000141506        0      0       0          0
# ENSG00000123200        1      0       0          0
# ENSG00000115602        0      0       1          0
# ENSG00000168743        0      0       0          0
# ENSG00000197430        0      0       0          0
# ENSG00000281038        0      0       0          0
# ENSG00000070366        0      0       0          1
# ENSG00000124091        0      0       0          1
# ENSG00000130307        0      0       0          0

# %%
def get_classification_averages_df(spreadsheet_df, labels_df):
    """
    Args:
        spreadsheet_df: genes x samples dataframe
        labels_df:      samples x catagories dataframe
    Returns:
        cluster_ave_df: genes x catagories dataframe where data is catagory row average
    """
    labels_dict = labels_df.to_dict()[1]
    cluster_numbers = list(np.unique(list(labels_dict.values())))
    labels = list(labels_dict.values())
    cluster_ave_df = pd.DataFrame({i: spreadsheet_df.iloc[:, labels == i].mean(axis=1) for i in cluster_numbers})
    return cluster_ave_df

# %%
cluster_ave_df = get_classification_averages_df(spreadsheet_df, labels_df)
cluster_ave_df
# Out:
#                    0         1         2
# ENSG00000158411  0.0  0.000000  0.000000
# ENSG00000214357  0.0  0.000000  0.000000
# ENSG00000258597  0.0  0.000000  0.000000
# ENSG00000134757  0.0  0.666667  0.000000
# ENSG00000155792  0.0  0.333333  0.333333
# ENSG00000049541  0.0  0.000000  0.000000
# ENSG00000115226  0.0  0.000000  0.000000
# ENSG00000125633  0.0  0.000000  0.000000
# ENSG00000243414  0.2  0.000000  0.000000
# ENSG00000102384  0.2  0.333333  0.000000
# ENSG00000121680  0.0  0.333333  0.000000
# ENSG00000187005  0.0  0.000000  0.000000
# ENSG00000009694  0.6  1.000000  0.666667
# ENSG00000111785  0.0  0.000000  0.000000
# ENSG00000128590  0.0  0.000000  0.333333
# ENSG00000141506  0.0  0.000000  0.000000
# ENSG00000123200  0.2  0.333333  0.333333
# ENSG00000115602  0.0  0.333333  0.000000
# ENSG00000168743  0.0  0.000000  0.000000
# ENSG00000197430  0.0  0.000000  0.000000
# ENSG00000281038  0.2  0.000000  0.000000
# ENSG00000070366  0.0  0.333333  0.333333
# ENSG00000124091  0.0  0.333333  0.000000
# ENSG00000130307  0.0  0.000000  0.333333
