# %% [markdown]
# ### KnowEnG-Research/Data_Cleanup_Pipeline March 13, 2017 ( GeneSet Characterization )
# * new improved data from aws - latest

# %%
import os
import sys

import time
import numpy as np
import pandas as pd

sys.path.insert(1, '../../KnowEnG_Pipelines_Library')
sys.path.insert(1, '../../KnowEnG_Pipelines_Library/knpackage')

sys.path.insert(1, '../../keg_test_tools/src')
import dcp_test

sys.path.insert(1, '../../Data_Cleanup_Pipeline/src/')
import data_cleanup_toolbox as dc

import knpackage.redis_utilities
import knpackage.toolbox as kn

# %%
yaml_dir = '../../Data_Cleanup_Pipeline/data/run_files'
yaml_file = 'TEMPLATE_data_cleanup.yml'
run_parameters = kn.get_run_parameters(yaml_dir, yaml_file)

run_parameters.pop('phenotype_full_path', None)
run_parameters['spreadsheet_data_dir'] = '../../keg_test_tools/data/geneset_characterization/spreadsheets_GSC'
run_parameters['pipeline_type'] = 'geneset_characterization_pipeline'
run_parameters['run_directory'] = '../../Data_Cleanup_Pipeline/src/'
run_parameters['results_directory'] = './run_dir/results'

for p in list(run_parameters.keys()):
    print(p, ':\t\t', run_parameters[p])
# Out:
# source_hint :
# taxonid :		 9606
# spreadsheet_name_full_path :		 ../data/spreadsheets/TEST_1_gene_expression.tsv
# spreadsheet_data_dir :		 ../../keg_test_tools/data/geneset_characterization/spreadsheets_GSC
# run_file :		 TEMPLATE_data_cleanup.yml
# pipeline_type :		 geneset_characterization_pipeline
# results_directory :		 ./run_dir/results
# run_directory :		 ../../Data_Cleanup_Pipeline/src/
# redis_credential :		 {'host': 'knowredis.knowhub.org', 'password': 'KnowEnG', 'port': 6379}

# %%
test_result_df = dcp_test.test_data_cleanup(run_parameters)
# Out:
# 	Start testing geneset_characterization_pipeline at Mon Mar 13 16:38:00 2017
#
#  spreadsheet_ALPHA_data_.G.GSC.tsv
#
#  spreadsheet_A_.G.GSC.tsv
#
#  spreadsheet_B_.G.GSC.tsv
#
#  spreadsheet_DNE_.G.GSC.tsv
#
#  spreadsheet_EMPTY_cols_.G.GSC.tsv
#
#  spreadsheet_EMPTY_rows_.G.GSC.tsv
#
#  spreadsheet_NAN_data_.G.GSC.tsv
#
#  spreadsheet_NA_cols_.G.GSC.tsv
#
#  spreadsheet_NA_rows_.G.GSC.tsv
#
#  spreadsheet_NAs_rows_and_cols_.G.GSC.tsv
#
#  spreadsheet_Negative_data_.G.GSC.tsv
#
#  spreadsheet_duplicate_cols_.G.GSC.tsv
#
#  spreadsheet_duplicate_rows_.G.GSC.tsv
#
#  spreadsheet_duplicates_rows_AND_cols_.G.GSC.tsv

# %%
test_result_df
# Out:
#                                                  genes  samples  \
# genes_x_samples
# spreadsheet_ALPHA_data_.G.GSC.tsv                  5.0      5.0
# spreadsheet_A_.G.GSC.tsv                           5.0      5.0
# spreadsheet_B_.G.GSC.tsv                           5.0      5.0
# spreadsheet_DNE_.G.GSC.tsv                         5.0      5.0
# spreadsheet_EMPTY_cols_.G.GSC.tsv                  0.0      4.0
# spreadsheet_EMPTY_rows_.G.GSC.tsv                  4.0      0.0
# spreadsheet_NAN_data_.G.GSC.tsv                    5.0      5.0
# spreadsheet_NA_cols_.G.GSC.tsv                     5.0      5.0
# spreadsheet_NA_rows_.G.GSC.tsv                     5.0      5.0
# spreadsheet_NAs_rows_and_cols_.G.GSC.tsv           5.0      5.0
# spreadsheet_Negative_data_.G.GSC.tsv               5.0      5.0
# spreadsheet_duplicate_cols_.G.GSC.tsv              5.0      5.0
# spreadsheet_duplicate_rows_.G.GSC.tsv              5.0      5.0
# spreadsheet_duplicates_rows_AND_cols_.G.GSC.tsv    5.0      5.0
#
#                                                  samples_phenotypes    s    p  \
# genes_x_samples
# spreadsheet_ALPHA_data_.G.GSC.tsv                               0.0  0.0  0.0
# spreadsheet_A_.G.GSC.tsv                                        0.0  0.0  0.0
# spreadsheet_B_.G.GSC.tsv                                        0.0  0.0  0.0
# spreadsheet_DNE_.G.GSC.tsv                                      0.0  0.0  0.0
# spreadsheet_EMPTY_cols_.G.GSC.tsv                               0.0  0.0  0.0
# spreadsheet_EMPTY_rows_.G.GSC.tsv                               0.0  0.0  0.0
# spreadsheet_NAN_data_.G.GSC.tsv                                 0.0  0.0  0.0
# spreadsheet_NA_cols_.G.GSC.tsv                                  0.0  0.0  0.0
# spreadsheet_NA_rows_.G.GSC.tsv                                  0.0  0.0  0.0
# spreadsheet_NAs_rows_and_cols_.G.GSC.tsv                        0.0  0.0  0.0
# spreadsheet_Negative_data_.G.GSC.tsv                            0.0  0.0  0.0
# spreadsheet_duplicate_cols_.G.GSC.tsv                           0.0  0.0  0.0
# spreadsheet_duplicate_rows_.G.GSC.tsv                           0.0  0.0  0.0
# spreadsheet_duplicates_rows_AND_cols_.G.GSC.tsv                 0.0  0.0  0.0
#
#                                                 validation_flag  \
# genes_x_samples
# spreadsheet_ALPHA_data_.G.GSC.tsv                         False
# spreadsheet_A_.G.GSC.tsv                                   True
# spreadsheet_B_.G.GSC.tsv                                   True
# spreadsheet_DNE_.G.GSC.tsv                                False
# spreadsheet_EMPTY_cols_.G.GSC.tsv                         False
# spreadsheet_EMPTY_rows_.G.GSC.tsv                         False
# spreadsheet_NAN_data_.G.GSC.tsv                           False
# spreadsheet_NA_cols_.G.GSC.tsv                             True
# spreadsheet_NA_rows_.G.GSC.tsv                             True
# spreadsheet_NAs_rows_and_cols_.G.GSC.tsv                   True
# spreadsheet_Negative_data_.G.GSC.tsv                      False
# spreadsheet_duplicate_cols_.G.GSC.tsv                      True
# spreadsheet_duplicate_rows_.G.GSC.tsv                      True
# spreadsheet_duplicates_rows_AND_cols_.G.GSC.tsv            True
#
#                                                                                            message  \
# genes_x_samples
# spreadsheet_ALPHA_data_.G.GSC.tsv                ./run_dir/results/log_spreadsheet_ALPHA_data_....
# spreadsheet_A_.G.GSC.tsv                            ./run_dir/results/log_spreadsheet_A_.G.GSC.tsv
# spreadsheet_B_.G.GSC.tsv                            ./run_dir/results/log_spreadsheet_B_.G.GSC.tsv
# spreadsheet_DNE_.G.GSC.tsv                        ./run_dir/results/log_spreadsheet_DNE_.G.GSC.tsv
# spreadsheet_EMPTY_cols_.G.GSC.tsv                ./run_dir/results/log_spreadsheet_EMPTY_cols_....
# spreadsheet_EMPTY_rows_.G.GSC.tsv                ./run_dir/results/log_spreadsheet_EMPTY_rows_....
# spreadsheet_NAN_data_.G.GSC.tsv                  ./run_dir/results/log_spreadsheet_NAN_data_.G....
# spreadsheet_NA_cols_.G.GSC.tsv                   ./run_dir/results/log_spreadsheet_NA_cols_.G.G...
# spreadsheet_NA_rows_.G.GSC.tsv                   ./run_dir/results/log_spreadsheet_NA_rows_.G.G...
# spreadsheet_NAs_rows_and_cols_.G.GSC.tsv         ./run_dir/results/log_spreadsheet_NAs_rows_and...
# spreadsheet_Negative_data_.G.GSC.tsv             ./run_dir/results/log_spreadsheet_Negative_dat...
# spreadsheet_duplicate_cols_.G.GSC.tsv            ./run_dir/results/log_spreadsheet_duplicate_co...
# spreadsheet_duplicate_rows_.G.GSC.tsv            ./run_dir/results/log_spreadsheet_duplicate_ro...
# spreadsheet_duplicates_rows_AND_cols_.G.GSC.tsv  ./run_dir/results/log_spreadsheet_duplicates_r...
#
#                                                  cleanup_time err_message
# genes_x_samples
# spreadsheet_ALPHA_data_.G.GSC.tsv                    0.003046
# spreadsheet_A_.G.GSC.tsv                             0.394980
# spreadsheet_B_.G.GSC.tsv                             0.621812
# spreadsheet_DNE_.G.GSC.tsv                           0.001549
# spreadsheet_EMPTY_cols_.G.GSC.tsv                    0.000580
# spreadsheet_EMPTY_rows_.G.GSC.tsv                    0.000481
# spreadsheet_NAN_data_.G.GSC.tsv                      0.000755
# spreadsheet_NA_cols_.G.GSC.tsv                       0.390480
# spreadsheet_NA_rows_.G.GSC.tsv                       0.337983
# spreadsheet_NAs_rows_and_cols_.G.GSC.tsv             0.342647
# spreadsheet_Negative_data_.G.GSC.tsv                 0.001241
# spreadsheet_duplicate_cols_.G.GSC.tsv                0.391198
# spreadsheet_duplicate_rows_.G.GSC.tsv                0.336992
# spreadsheet_duplicates_rows_AND_cols_.G.GSC.tsv      0.341424
