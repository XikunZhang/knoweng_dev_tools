# %% [markdown]
# ## KnowEnG-Research/Data_Cleanup_Pipeline March 13, 2017 ( Samples Clustering )
# * new improved data from aws - latest

# %%
import os
import sys

import time
import numpy as np
import pandas as pd

sys.path.insert(1, '../../KnowEnG_Pipelines_Library')
sys.path.insert(1, '../../KnowEnG_Pipelines_Library/knpackage')

sys.path.insert(1, '../../keg_test_tools/src')
import dcp_test

sys.path.insert(1, '../../Data_Cleanup_Pipeline/src/')
import data_cleanup_toolbox as dc

import knpackage.redis_utilities
import knpackage.toolbox as kn

# %%
yaml_dir = '../../Data_Cleanup_Pipeline/data/run_files'
yaml_file = 'TEMPLATE_data_cleanup.yml'
run_parameters = kn.get_run_parameters(yaml_dir, yaml_file)   

run_parameters['pheno_data_dir'] = '../../keg_test_tools/data/samples_clustering/phenotypes_SC'
run_parameters['spreadsheet_data_dir'] = '../../keg_test_tools/data/samples_clustering/spreadsheets_SC'
run_parameters['pipeline_type'] = 'samples_clustering_pipeline'
run_parameters['run_directory'] = '../../Data_Cleanup_Pipeline/src/'
run_parameters['results_directory'] = './run_dir/results'

for p in list(run_parameters.keys()):
    print(p, ':\t\t', run_parameters[p])
# Out:
# spreadsheet_data_dir :		 ../../keg_test_tools/data/samples_clustering/spreadsheets_SC
# pipeline_type :		 samples_clustering_pipeline
# pheno_data_dir :		 ../../keg_test_tools/data/samples_clustering/phenotypes_SC
# results_directory :		 ./run_dir/results
# spreadsheet_name_full_path :		 ../data/spreadsheets/TEST_1_gene_expression.tsv
# run_directory :		 ../../Data_Cleanup_Pipeline/src/
# redis_credential :		 {'host': 'knowredis.knowhub.org', 'password': 'KnowEnG', 'port': 6379}
# source_hint :
# taxonid :		 9606
# phenotype_full_path :		 ../data/spreadsheets/TEST_1_phenotype.tsv
# run_file :		 TEMPLATE_data_cleanup.yml

# %%
test_result_df = dcp_test.test_data_cleanup(run_parameters)
# Out:
# 	Start testing samples_clustering_pipeline at Mon Mar 13 16:36:13 2017
#
#  spreadsheet_ALPHA_data_.G.SC.tsv
# 	 spreadsheet_ALPHA_data_.P.SC_pheno.tsv
#
#  spreadsheet_A_.G.SC.tsv
# 	 spreadsheet_A_.P.SC_pheno.tsv
#
#  spreadsheet_B_.G.SC.tsv
# 	 spreadsheet_B_.P.SC_pheno.tsv
#
#  spreadsheet_DNE_.G.SC.tsv
# 	 spreadsheet_DNE_.P.SC_pheno.tsv
#
#  spreadsheet_EMPTY_cols_.G.SC.tsv
# 	 spreadsheet_EMPTY_cols_.P.SC_pheno.tsv
#
#  spreadsheet_EMPTY_rows_.G.SC.tsv
# 	 spreadsheet_EMPTY_rows_.P.SC_pheno.tsv
#
#  spreadsheet_NAN_data_.G.SC.tsv
# 	 spreadsheet_NAN_data_.P.SC_pheno.tsv
#
#  spreadsheet_NA_cols_.G.SC.tsv
# 	 spreadsheet_NA_cols_.P.SC_pheno.tsv
#
#  spreadsheet_NA_rows_.G.SC.tsv
# 	 spreadsheet_NA_rows_.P.SC_pheno.tsv
#
#  spreadsheet_NAs_rows_and_cols_.G.SC.tsv
# 	 spreadsheet_NAs_rows_and_cols_.P.SC_pheno.tsv
#
#  spreadsheet_Negative_data_.G.SC.tsv
# 	 spreadsheet_Negative_data_.P.SC_pheno.tsv
#
#  spreadsheet_duplicate_cols_.G.SC.tsv
# 	 spreadsheet_duplicate_cols_.P.SC_pheno.tsv
#
#  spreadsheet_duplicate_rows_.G.SC.tsv
# 	 spreadsheet_duplicate_rows_.P.SC_pheno.tsv
#
#  spreadsheet_duplicates_rows_AND_cols_.G.SC.tsv
# 	 spreadsheet_duplicates_rows_AND_cols_.P.SC_pheno.tsv

# %%
test_result_df
# Out:
#                                                 genes  samples  \
# spreadsheet_ALPHA_data_.G.SC.tsv                  5.0      5.0
# spreadsheet_A_.G.SC.tsv                           5.0      5.0
# spreadsheet_B_.G.SC.tsv                           5.0      5.0
# spreadsheet_DNE_.G.SC.tsv                         5.0      5.0
# spreadsheet_EMPTY_cols_.G.SC.tsv                  0.0      4.0
# spreadsheet_EMPTY_rows_.G.SC.tsv                  4.0      0.0
# spreadsheet_NAN_data_.G.SC.tsv                    5.0      5.0
# spreadsheet_NA_cols_.G.SC.tsv                     5.0      5.0
# spreadsheet_NA_rows_.G.SC.tsv                     5.0      5.0
# spreadsheet_NAs_rows_and_cols_.G.SC.tsv           5.0      5.0
# spreadsheet_Negative_data_.G.SC.tsv               5.0      5.0
# spreadsheet_duplicate_cols_.G.SC.tsv              5.0      5.0
# spreadsheet_duplicate_rows_.G.SC.tsv              5.0      5.0
# spreadsheet_duplicates_rows_AND_cols_.G.SC.tsv    5.0      5.0
#
#                                                                                samples_phenotypes  \
# spreadsheet_ALPHA_data_.G.SC.tsv                           spreadsheet_ALPHA_data_.P.SC_pheno.tsv
# spreadsheet_A_.G.SC.tsv                                             spreadsheet_A_.P.SC_pheno.tsv
# spreadsheet_B_.G.SC.tsv                                             spreadsheet_B_.P.SC_pheno.tsv
# spreadsheet_DNE_.G.SC.tsv                                         spreadsheet_DNE_.P.SC_pheno.tsv
# spreadsheet_EMPTY_cols_.G.SC.tsv                           spreadsheet_EMPTY_cols_.P.SC_pheno.tsv
# spreadsheet_EMPTY_rows_.G.SC.tsv                           spreadsheet_EMPTY_rows_.P.SC_pheno.tsv
# spreadsheet_NAN_data_.G.SC.tsv                               spreadsheet_NAN_data_.P.SC_pheno.tsv
# spreadsheet_NA_cols_.G.SC.tsv                                 spreadsheet_NA_cols_.P.SC_pheno.tsv
# spreadsheet_NA_rows_.G.SC.tsv                                 spreadsheet_NA_rows_.P.SC_pheno.tsv
# spreadsheet_NAs_rows_and_cols_.G.SC.tsv             spreadsheet_NAs_rows_and_cols_.P.SC_pheno.tsv
# spreadsheet_Negative_data_.G.SC.tsv                     spreadsheet_Negative_data_.P.SC_pheno.tsv
# spreadsheet_duplicate_cols_.G.SC.tsv                   spreadsheet_duplicate_cols_.P.SC_pheno.tsv
# spreadsheet_duplicate_rows_.G.SC.tsv                   spreadsheet_duplicate_rows_.P.SC_pheno.tsv
# spreadsheet_duplicates_rows_AND_cols_.G.SC.tsv  spreadsheet_duplicates_rows_AND_cols_.P.SC_phe...
#
#                                                   s    p validation_flag  \
# spreadsheet_ALPHA_data_.G.SC.tsv                5.0  5.0           False
# spreadsheet_A_.G.SC.tsv                         5.0  5.0            True
# spreadsheet_B_.G.SC.tsv                         5.0  5.0            True
# spreadsheet_DNE_.G.SC.tsv                       5.0  5.0           False
# spreadsheet_EMPTY_cols_.G.SC.tsv                0.0  5.0           False
# spreadsheet_EMPTY_rows_.G.SC.tsv                5.0  0.0           False
# spreadsheet_NAN_data_.G.SC.tsv                  5.0  5.0           False
# spreadsheet_NA_cols_.G.SC.tsv                   5.0  5.0            True
# spreadsheet_NA_rows_.G.SC.tsv                   5.0  5.0            True
# spreadsheet_NAs_rows_and_cols_.G.SC.tsv         5.0  5.0            True
# spreadsheet_Negative_data_.G.SC.tsv             5.0  5.0            True
# spreadsheet_duplicate_cols_.G.SC.tsv            5.0  5.0            True
# spreadsheet_duplicate_rows_.G.SC.tsv            5.0  5.0            True
# spreadsheet_duplicates_rows_AND_cols_.G.SC.tsv  5.0  5.0            True
#
#                                                                                           message  \
# spreadsheet_ALPHA_data_.G.SC.tsv                ./run_dir/results/log_spreadsheet_ALPHA_data_....
# spreadsheet_A_.G.SC.tsv                         ./run_dir/results/log_spreadsheet_A_.G.SC.tsvs...
# spreadsheet_B_.G.SC.tsv                         ./run_dir/results/log_spreadsheet_B_.G.SC.tsvs...
# spreadsheet_DNE_.G.SC.tsv                       ./run_dir/results/log_spreadsheet_DNE_.G.SC.ts...
# spreadsheet_EMPTY_cols_.G.SC.tsv                ./run_dir/results/log_spreadsheet_EMPTY_cols_....
# spreadsheet_EMPTY_rows_.G.SC.tsv                ./run_dir/results/log_spreadsheet_EMPTY_rows_....
# spreadsheet_NAN_data_.G.SC.tsv                  ./run_dir/results/log_spreadsheet_NAN_data_.G....
# spreadsheet_NA_cols_.G.SC.tsv                   ./run_dir/results/log_spreadsheet_NA_cols_.G.S...
# spreadsheet_NA_rows_.G.SC.tsv                   ./run_dir/results/log_spreadsheet_NA_rows_.G.S...
# spreadsheet_NAs_rows_and_cols_.G.SC.tsv         ./run_dir/results/log_spreadsheet_NAs_rows_and...
# spreadsheet_Negative_data_.G.SC.tsv             ./run_dir/results/log_spreadsheet_Negative_dat...
# spreadsheet_duplicate_cols_.G.SC.tsv            ./run_dir/results/log_spreadsheet_duplicate_co...
# spreadsheet_duplicate_rows_.G.SC.tsv            ./run_dir/results/log_spreadsheet_duplicate_ro...
# spreadsheet_duplicates_rows_AND_cols_.G.SC.tsv  ./run_dir/results/log_spreadsheet_duplicates_r...
#
#                                                 cleanup_time err_message
# spreadsheet_ALPHA_data_.G.SC.tsv                    0.003366
# spreadsheet_A_.G.SC.tsv                             0.394712
# spreadsheet_B_.G.SC.tsv                             0.621703
# spreadsheet_DNE_.G.SC.tsv                           0.393905
# spreadsheet_EMPTY_cols_.G.SC.tsv                    0.000954
# spreadsheet_EMPTY_rows_.G.SC.tsv                    0.000678
# spreadsheet_NAN_data_.G.SC.tsv                      0.001245
# spreadsheet_NA_cols_.G.SC.tsv                       0.392520
# spreadsheet_NA_rows_.G.SC.tsv                       0.344365
# spreadsheet_NAs_rows_and_cols_.G.SC.tsv             0.343632
# spreadsheet_Negative_data_.G.SC.tsv                 0.394560
# spreadsheet_duplicate_cols_.G.SC.tsv                0.393127
# spreadsheet_duplicate_rows_.G.SC.tsv                0.345228
# spreadsheet_duplicates_rows_AND_cols_.G.SC.tsv      0.344966
